# %%
# All Questions

# %%
from difflib import SequenceMatcher


def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP1/mlp_all_ques_'+str(i)+'_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                #print(act_ans)
                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(match_ratio == 1.0):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio >= 0.7):
                        p_hits += 1
                        break
                
                
        if(n == 0):
            count += 1
            
    print("\nAll Questions: \n")
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
    
    try:
        e_p = (e_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Exact_match: %.3f" %(e_p)+"%")
        
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
    try:
        p_p = (p_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Partial_match: %.3f" %(p_p)+'%')
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
print(len(predicted_questions))
# Out:
# All Questions:
#
# K =  10
#
# 617
#
# Percentage of
# Exact_match: 2.107%
# Percentage of
# Partial_match: 18.152%
#
# All Questions:
#
# K =  20
#
# 627
#
# Percentage of
# Exact_match: 2.073%
# Percentage of
# Partial_match: 19.617%
#
# All Questions:
#
# K =  30
#
# 613
#
# Percentage of
# Exact_match: 2.284%
# Percentage of
# Partial_match: 19.739%
#
# All Questions:
#
# K =  40
#
# 614
#
# Percentage of
# Exact_match: 2.280%
# Percentage of
# Partial_match: 20.033%
# 933

# %%
# All Questions using cosine similarity for exact match

# %%
from difflib import SequenceMatcher
import re
from nltk.tokenize import word_tokenize

def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


actual_answers_string = ' '.join(actual_answers)
actual_answers_tokens =  word_tokenize(actual_answers_string) #re.findall('[\w]+',actual_answers_string)
actual_answers_unique_tokens = list(set(actual_answers_tokens))
#print(actual_answers_unique_tokens,'\n')


integer_encoding = {}
for i,word in enumerate(actual_answers_unique_tokens):
        
    integer_encoding[word] = i

#print(integer_encoding)

def integer_encoding1(subset_sentence):
    subset_sentence_tokens =  word_tokenize(subset_sentence) #re.findall('[\w]+',subset_sentence)
    subset_sentence_tokens_encoded = {}
    for i in subset_sentence_tokens:
        j = i
        if (j not in integer_encoding.keys()):
            integer_encoding[j] = len(integer_encoding)
        subset_sentence_tokens_encoded[j] = integer_encoding[j]
        #subset_sentence_tokens_encoded.append(integer_encoding[i])
    return (subset_sentence_tokens_encoded)



for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP1/mlp_all_ques_'+str(i)+'_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                in1 = integer_encoding1(pred_ans)
                #print(in1)
                in2 = integer_encoding1(act_ans)
                #print(in2)
                
                
                
                import math
                def Cosine_Similarity(vec1, vec2):
                    common = set(vec1.keys()) & set(vec2.keys())
                    numerator = sum([vec1[x] * vec2[x] for x in common])
                    
                    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
                    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
                    denominator = (math.sqrt(sum1) * math.sqrt(sum2))
                    if not denominator:
                        return(0.0)
                    
                    else:
                        return(round(float(numerator) / denominator,1))
                
                cosine_similar = Cosine_Similarity(in1,in2)
                                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(cosine_similar == 1):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio>=0.7):
                        p_hits += 1
                        break
                
                #if(match_ratio == 1.0):
                    #e_hits += 1
                    #p_hits += 1
                    #break
                #else:
                    #if(match_ratio >= 0.7):
                        #p_hits += 1
                        #break
                
                
        if(n == 0):
            count += 1
    
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
            
    print("\nAll Questions: \n")
    print("Percentage of\n"+"Exact_match: %.3f" %((e_hits/(len(predicted_questions)-count))*100)+"%")
    print("Percentage of\n"+"Partial_match: %.3f" %((p_hits/(len(predicted_questions)-count))*100)+'%')
print(len(predicted_questions))
# Out:
# K =  10
#
# 617
#
#
# All Questions:
#
# Percentage of
# Exact_match: 13.452%
# Percentage of
# Partial_match: 18.476%
# K =  20
#
# 627
#
#
# All Questions:
#
# Percentage of
# Exact_match: 13.397%
# Percentage of
# Partial_match: 19.777%
# K =  30
#
# 613
#
#
# All Questions:
#
# Percentage of
# Exact_match: 13.214%
# Percentage of
# Partial_match: 19.739%
# K =  40
#
# 614
#
#
# All Questions:
#
# Percentage of
# Exact_match: 13.029%
# Percentage of
# Partial_match: 20.033%
# 933

# %%
#  Date

# %%
from difflib import SequenceMatcher


def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP/Date/mlp_date_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(match_ratio == 1.0):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio >= 0.7):
                        p_hits += 1
                        break
                
                
        if(n == 0):
            count += 1
            
    print("\nDate: \n")
    print('K = ',i,'\n')
    print(len(predicted_questions)-count)
    
    print("Percentage of\n"+"Exact_match: %.3f" %((e_hits/(len(predicted_questions)-count))*100)+"%")
    print("Percentage of\n"+"Partial_match: %.3f" %((p_hits/(len(predicted_questions)-count))*100)+'%')
print(len(predicted_questions))
# Out:
# Date:
#
# K =  10
#
# 102
# Percentage of
# Exact_match: 10.784%
# Percentage of
# Partial_match: 17.647%
#
# Date:
#
# K =  20
#
# 102
# Percentage of
# Exact_match: 10.784%
# Percentage of
# Partial_match: 27.451%
#
# Date:
#
# K =  30
#
# 98
# Percentage of
# Exact_match: 14.286%
# Percentage of
# Partial_match: 28.571%
#
# Date:
#
# K =  40
#
# 102
# Percentage of
# Exact_match: 11.765%
# Percentage of
# Partial_match: 27.451%
# 109

# %%
# Date using cosine similarity for exact match

# %%
from difflib import SequenceMatcher
import re
from nltk.tokenize import word_tokenize

def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


actual_answers_string = ' '.join(actual_answers)
actual_answers_tokens =  word_tokenize(actual_answers_string) #re.findall('[\w]+',actual_answers_string)
actual_answers_unique_tokens = list(set(actual_answers_tokens))
#print(actual_answers_unique_tokens,'\n')


integer_encoding = {}
for i,word in enumerate(actual_answers_unique_tokens):
        
    integer_encoding[word] = i

#print(integer_encoding)

def integer_encoding1(subset_sentence):
    subset_sentence_tokens =  word_tokenize(subset_sentence) #re.findall('[\w]+',subset_sentence)
    subset_sentence_tokens_encoded = {}
    for i in subset_sentence_tokens:
        j = i
        if (j not in integer_encoding.keys()):
            integer_encoding[j] = len(integer_encoding)
        subset_sentence_tokens_encoded[j] = integer_encoding[j]
        #subset_sentence_tokens_encoded.append(integer_encoding[i])
    return (subset_sentence_tokens_encoded)



for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP1/Date/MLP_date_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                in1 = integer_encoding1(pred_ans)
                #print(in1)
                in2 = integer_encoding1(act_ans)
                #print(in2)
                
                
                
                import math
                def Cosine_Similarity(vec1, vec2):
                    common = set(vec1.keys()) & set(vec2.keys())
                    numerator = sum([vec1[x] * vec2[x] for x in common])
                    
                    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
                    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
                    denominator = (math.sqrt(sum1) * math.sqrt(sum2))
                    if not denominator:
                        return(0.0)
                    
                    else:
                        return(round(float(numerator) / denominator,1))
                
                cosine_similar = Cosine_Similarity(in1,in2)
                                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(cosine_similar == 1):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio>=0.7):
                        p_hits += 1
                        break
                
                #if(match_ratio == 1.0):
                    #e_hits += 1
                    #p_hits += 1
                    #break
                #else:
                    #if(match_ratio >= 0.7):
                        #p_hits += 1
                        #break
                
                
        if(n == 0):
            count += 1
    
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
            
    print("\nDate: \n")
    print("Percentage of\n"+"Exact_match: %.3f" %((e_hits/(len(predicted_questions)-count))*100)+"%")
    print("Percentage of\n"+"Partial_match: %.3f" %((p_hits/(len(predicted_questions)-count))*100)+'%')
print(len(predicted_questions))
# Out:
# K =  10
#
# 102
#
#
# Date:
#
# Percentage of
# Exact_match: 13.725%
# Percentage of
# Partial_match: 19.608%
# K =  20
#
# 102
#
#
# Date:
#
# Percentage of
# Exact_match: 15.686%
# Percentage of
# Partial_match: 28.431%
# K =  30
#
# 98
#
#
# Date:
#
# Percentage of
# Exact_match: 17.347%
# Percentage of
# Partial_match: 28.571%
# K =  40
#
# 102
#
#
# Date:
#
# Percentage of
# Exact_match: 14.706%
# Percentage of
# Partial_match: 27.451%
# 109

# %%
# Percent

# %%
from difflib import SequenceMatcher


def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP1/Percent/mlp_prc_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                #print(act_ans)
                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(match_ratio == 1.0):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio >= 0.7):
                        p_hits += 1
                        break
                
                
        if(n == 0):
            count += 1
            
    print("\nPercent: \n")
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
    
    try:
        e_p = (e_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Exact_match: %.3f" %(e_p)+"%")
        
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
    try:
        p_p = (p_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Partial_match: %.3f" %(p_p)+'%')
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
print(len(predicted_questions))
# Out:
# Percent:
#
# K =  10
#
# 1
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
#
# Percent:
#
# K =  20
#
# 1
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
#
# Percent:
#
# K =  30
#
# 1
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
#
# Percent:
#
# K =  40
#
# 1
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
# 1

# %%
# Percent using cosine similarity for exact match

# %%
from difflib import SequenceMatcher
import re
from nltk.tokenize import word_tokenize

def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


actual_answers_string = ' '.join(actual_answers)
actual_answers_tokens =  word_tokenize(actual_answers_string) #re.findall('[\w]+',actual_answers_string)
actual_answers_unique_tokens = list(set(actual_answers_tokens))
#print(actual_answers_unique_tokens,'\n')


integer_encoding = {}
for i,word in enumerate(actual_answers_unique_tokens):
        
    integer_encoding[word] = i

#print(integer_encoding)

def integer_encoding1(subset_sentence):
    subset_sentence_tokens =  word_tokenize(subset_sentence) #re.findall('[\w]+',subset_sentence)
    subset_sentence_tokens_encoded = {}
    for i in subset_sentence_tokens:
        j = i
        if (j not in integer_encoding.keys()):
            integer_encoding[j] = len(integer_encoding)
        subset_sentence_tokens_encoded[j] = integer_encoding[j]
        #subset_sentence_tokens_encoded.append(integer_encoding[i])
    return (subset_sentence_tokens_encoded)



for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP1/Percent/MLP_prc_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                in1 = integer_encoding1(pred_ans)
                #print(in1)
                in2 = integer_encoding1(act_ans)
                #print(in2)
                
                
                
                import math
                def Cosine_Similarity(vec1, vec2):
                    common = set(vec1.keys()) & set(vec2.keys())
                    numerator = sum([vec1[x] * vec2[x] for x in common])
                    
                    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
                    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
                    denominator = (math.sqrt(sum1) * math.sqrt(sum2))
                    if not denominator:
                        return(0.0)
                    
                    else:
                        return(round(float(numerator) / denominator,1))
                
                cosine_similar = Cosine_Similarity(in1,in2)
                                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(cosine_similar == 1):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio>=0.7):
                        p_hits += 1
                        break
                
                #if(match_ratio == 1.0):
                    #e_hits += 1
                    #p_hits += 1
                    #break
                #else:
                    #if(match_ratio >= 0.7):
                        #p_hits += 1
                        #break
                
                
        if(n == 0):
            count += 1
    
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
            
    print("\nPercent: \n")
    print("Percentage of\n"+"Exact_match: %.3f" %((e_hits/(len(predicted_questions)-count))*100)+"%")
    print("Percentage of\n"+"Partial_match: %.3f" %((p_hits/(len(predicted_questions)-count))*100)+'%')
print(len(predicted_questions))
# Out:
# K =  10
#
# 1
#
#
# Percent:
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
# K =  20
#
# 1
#
#
# Percent:
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
# K =  30
#
# 1
#
#
# Percent:
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
# K =  40
#
# 1
#
#
# Percent:
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
# 1

# %%
# Organization

# %%
from difflib import SequenceMatcher


def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP1/Organization/mlp_org_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                #print(act_ans)
                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(match_ratio == 1.0):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio >= 0.7):
                        p_hits += 1
                        break
                
                
        if(n == 0):
            count += 1
    
    print("\nOrganization: \n")
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
    
    try:
        e_p = (e_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Exact_match: %.3f" %(e_p)+"%")
        
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
    try:
        p_p = (p_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Partial_match: %.3f" %(p_p)+'%')
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
print(len(predicted_questions))
# Out:
# Organization:
#
# K =  10
#
# 3
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
#
# Organization:
#
# K =  20
#
# 3
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
#
# Organization:
#
# K =  30
#
# 3
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
#
# Organization:
#
# K =  40
#
# 3
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
# 3

# %%
# Organization using cosine similarity for exact match

# %%
from difflib import SequenceMatcher
import re
from nltk.tokenize import word_tokenize

def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


actual_answers_string = ' '.join(actual_answers)
actual_answers_tokens =  word_tokenize(actual_answers_string) #re.findall('[\w]+',actual_answers_string)
actual_answers_unique_tokens = list(set(actual_answers_tokens))
#print(actual_answers_unique_tokens,'\n')


integer_encoding = {}
for i,word in enumerate(actual_answers_unique_tokens):
        
    integer_encoding[word] = i

#print(integer_encoding)

def integer_encoding1(subset_sentence):
    subset_sentence_tokens =  word_tokenize(subset_sentence) #re.findall('[\w]+',subset_sentence)
    subset_sentence_tokens_encoded = {}
    for i in subset_sentence_tokens:
        j = i
        if (j not in integer_encoding.keys()):
            integer_encoding[j] = len(integer_encoding)
        subset_sentence_tokens_encoded[j] = integer_encoding[j]
        #subset_sentence_tokens_encoded.append(integer_encoding[i])
    return (subset_sentence_tokens_encoded)



for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP1/Organization/MLP_org_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                in1 = integer_encoding1(pred_ans)
                #print(in1)
                in2 = integer_encoding1(act_ans)
                #print(in2)
                
                
                
                import math
                def Cosine_Similarity(vec1, vec2):
                    common = set(vec1.keys()) & set(vec2.keys())
                    numerator = sum([vec1[x] * vec2[x] for x in common])
                    
                    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
                    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
                    denominator = (math.sqrt(sum1) * math.sqrt(sum2))
                    if not denominator:
                        return(0.0)
                    
                    else:
                        return(round(float(numerator) / denominator,1))
                
                cosine_similar = Cosine_Similarity(in1,in2)
                                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(cosine_similar == 1):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio>=0.7):
                        p_hits += 1
                        break
                
                #if(match_ratio == 1.0):
                    #e_hits += 1
                    #p_hits += 1
                    #break
                #else:
                    #if(match_ratio >= 0.7):
                        #p_hits += 1
                        #break
                
                
        if(n == 0):
            count += 1
    
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
            
    print("\nOrganization: \n")
    print("Percentage of\n"+"Exact_match: %.3f" %((e_hits/(len(predicted_questions)-count))*100)+"%")
    print("Percentage of\n"+"Partial_match: %.3f" %((p_hits/(len(predicted_questions)-count))*100)+'%')
print(len(predicted_questions))
# Out:
# K =  10
#
# 3
#
#
# Organization:
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
# K =  20
#
# 3
#
#
# Organization:
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
# K =  30
#
# 3
#
#
# Organization:
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
# K =  40
#
# 3
#
#
# Organization:
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 0.000%
# 3

# %%
# Time

# %%
from difflib import SequenceMatcher


def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP/Time/mlp_time_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        #print(parts)
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                #print(act_ans)
                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(match_ratio == 1.0):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio >= 0.7):
                        p_hits += 1
                        break
                
                
        if(n == 0):
            count += 1
            
    print("\nTime: \n")
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
    
    try:
        e_p = (e_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Exact_match: %.3f" %(e_p)+"%")
        
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
    try:
        p_p = (p_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Partial_match: %.3f" %(p_p)+'%')
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
print(len(predicted_questions))
# Out:
# Time:
#
# K =  10
#
# 16
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 31.250%
#
# Time:
#
# K =  20
#
# 16
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 31.250%
#
# Time:
#
# K =  30
#
# 16
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 25.000%
#
# Time:
#
# K =  40
#
# 14
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 21.429%
# 15

# %%
# Time using cosine similarity for exact match

# %%
from difflib import SequenceMatcher
import re
from nltk.tokenize import word_tokenize

def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


actual_answers_string = ' '.join(actual_answers)
actual_answers_tokens =  word_tokenize(actual_answers_string) #re.findall('[\w]+',actual_answers_string)
actual_answers_unique_tokens = list(set(actual_answers_tokens))
#print(actual_answers_unique_tokens,'\n')


integer_encoding = {}
for i,word in enumerate(actual_answers_unique_tokens):
        
    integer_encoding[word] = i

#print(integer_encoding)

def integer_encoding1(subset_sentence):
    subset_sentence_tokens =  word_tokenize(subset_sentence) #re.findall('[\w]+',subset_sentence)
    subset_sentence_tokens_encoded = {}
    for i in subset_sentence_tokens:
        j = i
        if (j not in integer_encoding.keys()):
            integer_encoding[j] = len(integer_encoding)
        subset_sentence_tokens_encoded[j] = integer_encoding[j]
        #subset_sentence_tokens_encoded.append(integer_encoding[i])
    return (subset_sentence_tokens_encoded)



for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP1/Time/MLP_time_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                in1 = integer_encoding1(pred_ans)
                #print(in1)
                in2 = integer_encoding1(act_ans)
                #print(in2)
                
                
                
                import math
                def Cosine_Similarity(vec1, vec2):
                    common = set(vec1.keys()) & set(vec2.keys())
                    numerator = sum([vec1[x] * vec2[x] for x in common])
                    
                    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
                    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
                    denominator = (math.sqrt(sum1) * math.sqrt(sum2))
                    if not denominator:
                        return(0.0)
                    
                    else:
                        return(round(float(numerator) / denominator,1))
                
                cosine_similar = Cosine_Similarity(in1,in2)
                                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(cosine_similar == 1):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio>=0.7):
                        p_hits += 1
                        break
                
                #if(match_ratio == 1.0):
                    #e_hits += 1
                    #p_hits += 1
                    #break
                #else:
                    #if(match_ratio >= 0.7):
                        #p_hits += 1
                        #break
                
                
        if(n == 0):
            count += 1
    
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
            
    print("\nTime: \n")
    print("Percentage of\n"+"Exact_match: %.3f" %((e_hits/(len(predicted_questions)-count))*100)+"%")
    print("Percentage of\n"+"Partial_match: %.3f" %((p_hits/(len(predicted_questions)-count))*100)+'%')
print(len(predicted_questions))
# Out:
# K =  10
#
# 16
#
#
# Time:
#
# Percentage of
# Exact_match: 6.250%
# Percentage of
# Partial_match: 31.250%
# K =  20
#
# 16
#
#
# Time:
#
# Percentage of
# Exact_match: 6.250%
# Percentage of
# Partial_match: 31.250%
# K =  30
#
# 16
#
#
# Time:
#
# Percentage of
# Exact_match: 6.250%
# Percentage of
# Partial_match: 25.000%
# K =  40
#
# 14
#
#
# Time:
#
# Percentage of
# Exact_match: 0.000%
# Percentage of
# Partial_match: 21.429%
# 15

# %%
# Number

# %%
from difflib import SequenceMatcher


def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP/Number/mlp_car_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        #print(parts)
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                #print(act_ans)
                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(match_ratio == 1.0):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio >= 0.7):
                        p_hits += 1
                        break
                
                
        if(n == 0):
            count += 1
            
    print("\nNumber: \n")
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
    
    try:
        e_p = (e_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Exact_match: %.3f" %(e_p)+"%")
        
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
    try:
        p_p = (p_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Partial_match: %.3f" %(p_p)+'%')
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
print(len(predicted_questions))
# Out:
# Number:
#
# K =  10
#
# 166
#
# Percentage of
# Exact_match: 7.831%
# Percentage of
# Partial_match: 16.867%
#
# Number:
#
# K =  20
#
# 166
#
# Percentage of
# Exact_match: 10.843%
# Percentage of
# Partial_match: 15.060%
#
# Number:
#
# K =  30
#
# 166
#
# Percentage of
# Exact_match: 11.446%
# Percentage of
# Partial_match: 14.458%
#
# Number:
#
# K =  40
#
# 166
#
# Percentage of
# Exact_match: 10.241%
# Percentage of
# Partial_match: 13.855%
# 167

# %%
# Number using cosine similarity for exact match

# %%
from difflib import SequenceMatcher
import re
from nltk.tokenize import word_tokenize

def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


actual_answers_string = ' '.join(actual_answers)
actual_answers_tokens =  word_tokenize(actual_answers_string) #re.findall('[\w]+',actual_answers_string)
actual_answers_unique_tokens = list(set(actual_answers_tokens))
#print(actual_answers_unique_tokens,'\n')


integer_encoding = {}
for i,word in enumerate(actual_answers_unique_tokens):
        
    integer_encoding[word] = i

#print(integer_encoding)

def integer_encoding1(subset_sentence):
    subset_sentence_tokens =  word_tokenize(subset_sentence) #re.findall('[\w]+',subset_sentence)
    subset_sentence_tokens_encoded = {}
    for i in subset_sentence_tokens:
        j = i
        if (j not in integer_encoding.keys()):
            integer_encoding[j] = len(integer_encoding)
        subset_sentence_tokens_encoded[j] = integer_encoding[j]
        #subset_sentence_tokens_encoded.append(integer_encoding[i])
    return (subset_sentence_tokens_encoded)



for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP1/Number/MLP_car_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                in1 = integer_encoding1(pred_ans)
                #print(in1)
                in2 = integer_encoding1(act_ans)
                #print(in2)
                
                
                
                import math
                def Cosine_Similarity(vec1, vec2):
                    common = set(vec1.keys()) & set(vec2.keys())
                    numerator = sum([vec1[x] * vec2[x] for x in common])
                    
                    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
                    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
                    denominator = (math.sqrt(sum1) * math.sqrt(sum2))
                    if not denominator:
                        return(0.0)
                    
                    else:
                        return(round(float(numerator) / denominator,1))
                
                cosine_similar = Cosine_Similarity(in1,in2)
                                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(cosine_similar == 1):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio>=0.7):
                        p_hits += 1
                        break
                
                #if(match_ratio == 1.0):
                    #e_hits += 1
                    #p_hits += 1
                    #break
                #else:
                    #if(match_ratio >= 0.7):
                        #p_hits += 1
                        #break
                
                
        if(n == 0):
            count += 1
    
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
            
    print("\nNumber: \n")
    print("Percentage of\n"+"Exact_match: %.3f" %((e_hits/(len(predicted_questions)-count))*100)+"%")
    print("Percentage of\n"+"Partial_match: %.3f" %((p_hits/(len(predicted_questions)-count))*100)+'%')
print(len(predicted_questions))
# Out:
# K =  10
#
# 166
#
#
# Number:
#
# Percentage of
# Exact_match: 14.458%
# Percentage of
# Partial_match: 16.867%
# K =  20
#
# 166
#
#
# Number:
#
# Percentage of
# Exact_match: 10.843%
# Percentage of
# Partial_match: 15.060%
# K =  30
#
# 166
#
#
# Number:
#
# Percentage of
# Exact_match: 11.446%
# Percentage of
# Partial_match: 14.458%
# K =  40
#
# 166
#
#
# Number:
#
# Percentage of
# Exact_match: 10.241%
# Percentage of
# Partial_match: 13.855%
# 167

# %%
# Person

# %%
from difflib import SequenceMatcher


def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP/Person/MLP_per_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        #print(parts)
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                #print(act_ans)
                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(match_ratio == 1.0):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio >= 0.7):
                        p_hits += 1
                        break
                
                
        if(n == 0):
            count += 1
            
    print("\nPerson: \n")
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
    
    try:
        e_p = (e_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Exact_match: %.3f" %(e_p)+"%")
        
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
    try:
        p_p = (p_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Partial_match: %.3f" %(p_p)+'%')
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
print(len(predicted_questions))
# Out:
# Person:
#
# K =  10
#
# 18
#
# Percentage of
# Exact_match: 16.667%
# Percentage of
# Partial_match: 16.667%
#
# Person:
#
# K =  20
#
# 18
#
# Percentage of
# Exact_match: 16.667%
# Percentage of
# Partial_match: 16.667%
#
# Person:
#
# K =  30
#
# 19
#
# Percentage of
# Exact_match: 15.789%
# Percentage of
# Partial_match: 42.105%
#
# Person:
#
# K =  40
#
# 18
#
# Percentage of
# Exact_match: 22.222%
# Percentage of
# Partial_match: 44.444%
# 315

# %%
# Person using cosine similarity for exact match

# %%
from difflib import SequenceMatcher
import re
from nltk.tokenize import word_tokenize

def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


actual_answers_string = ' '.join(actual_answers)
actual_answers_tokens =  word_tokenize(actual_answers_string) #re.findall('[\w]+',actual_answers_string)
actual_answers_unique_tokens = list(set(actual_answers_tokens))
#print(actual_answers_unique_tokens,'\n')


integer_encoding = {}
for i,word in enumerate(actual_answers_unique_tokens):
        
    integer_encoding[word] = i

#print(integer_encoding)

def integer_encoding1(subset_sentence):
    subset_sentence_tokens =  word_tokenize(subset_sentence) #re.findall('[\w]+',subset_sentence)
    subset_sentence_tokens_encoded = {}
    for i in subset_sentence_tokens:
        j = i
        if (j not in integer_encoding.keys()):
            integer_encoding[j] = len(integer_encoding)
        subset_sentence_tokens_encoded[j] = integer_encoding[j]
        #subset_sentence_tokens_encoded.append(integer_encoding[i])
    return (subset_sentence_tokens_encoded)



for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP1/Person/MLP_per_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                in1 = integer_encoding1(pred_ans)
                #print(in1)
                in2 = integer_encoding1(act_ans)
                #print(in2)
                
                
                
                import math
                def Cosine_Similarity(vec1, vec2):
                    common = set(vec1.keys()) & set(vec2.keys())
                    numerator = sum([vec1[x] * vec2[x] for x in common])
                    
                    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
                    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
                    denominator = (math.sqrt(sum1) * math.sqrt(sum2))
                    if not denominator:
                        return(0.0)
                    
                    else:
                        return(round(float(numerator) / denominator,1))
                
                cosine_similar = Cosine_Similarity(in1,in2)
                                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(cosine_similar == 1):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio>=0.7):
                        p_hits += 1
                        break
                
                #if(match_ratio == 1.0):
                    #e_hits += 1
                    #p_hits += 1
                    #break
                #else:
                    #if(match_ratio >= 0.7):
                        #p_hits += 1
                        #break
                
                
        if(n == 0):
            count += 1
    
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
            
    print("\nPerson: \n")
    print("Percentage of\n"+"Exact_match: %.3f" %((e_hits/(len(predicted_questions)-count))*100)+"%")
    print("Percentage of\n"+"Partial_match: %.3f" %((p_hits/(len(predicted_questions)-count))*100)+'%')
print(len(predicted_questions))
# Out:
# K =  10
#
# 18
#
#
# Person:
#
# Percentage of
# Exact_match: 16.667%
# Percentage of
# Partial_match: 16.667%
# K =  20
#
# 18
#
#
# Person:
#
# Percentage of
# Exact_match: 16.667%
# Percentage of
# Partial_match: 16.667%
# K =  30
#
# 19
#
#
# Person:
#
# Percentage of
# Exact_match: 15.789%
# Percentage of
# Partial_match: 42.105%
# K =  40
#
# 18
#
#
# Person:
#
# Percentage of
# Exact_match: 22.222%
# Percentage of
# Partial_match: 44.444%
# 315

# %%
# Location

# %%
from difflib import SequenceMatcher


def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP/Location/MLP_loc_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        #print(parts)
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                #print(act_ans)
                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(match_ratio == 1.0):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio >= 0.7):
                        p_hits += 1
                        break
                
                
        if(n == 0):
            count += 1
            
    print("\nLocation: \n")
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
    
    try:
        e_p = (e_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Exact_match: %.3f" %(e_p)+"%")
        
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
    try:
        p_p = (p_hits/(len(predicted_questions)-count))*100
        print("Percentage of\n"+"Partial_match: %.3f" %(p_p)+'%')
    except Exception as e:
        print(e)
        print("No matching questions in the testing file")
print(len(predicted_questions))
# Out:
# Location:
#
# K =  10
#
# 311
#
# Percentage of
# Exact_match: 13.826%
# Percentage of
# Partial_match: 20.257%
#
# Location:
#
# K =  20
#
# 321
#
# Percentage of
# Exact_match: 15.265%
# Percentage of
# Partial_match: 21.184%
#
# Location:
#
# K =  30
#
# 310
#
# Percentage of
# Exact_match: 13.871%
# Percentage of
# Partial_match: 20.323%
#
# Location:
#
# K =  40
#
# 310
#
# Percentage of
# Exact_match: 14.839%
# Percentage of
# Partial_match: 21.613%
# 323

# %%
# Location using cosine similarity for exact match

# %%
from difflib import SequenceMatcher
import re
from nltk.tokenize import word_tokenize

def ans_matching(a,b):
    return(round(SequenceMatcher(None,a,b).ratio(),1))


actual_questions = []
actual_answers = []
file = open('QA_Pair_testing_file.txt','rb')
for l in file:
    l = l.decode('utf-8').split('\n')[0]
    a_q = l.split(':::')
    a = a_q[0]
    actual_answers.append(a)
    q = a_q[1]
    actual_questions.append(q)
#print(actual_questions,'\n')
#print(len(actual_questions))
#print(actual_answers,'\n\n')
#print(len(actual_answers))


actual_answers_string = ' '.join(actual_answers)
actual_answers_tokens =  word_tokenize(actual_answers_string) #re.findall('[\w]+',actual_answers_string)
actual_answers_unique_tokens = list(set(actual_answers_tokens))
#print(actual_answers_unique_tokens,'\n')


integer_encoding = {}
for i,word in enumerate(actual_answers_unique_tokens):
        
    integer_encoding[word] = i

#print(integer_encoding)

def integer_encoding1(subset_sentence):
    subset_sentence_tokens =  word_tokenize(subset_sentence) #re.findall('[\w]+',subset_sentence)
    subset_sentence_tokens_encoded = {}
    for i in subset_sentence_tokens:
        j = i
        if (j not in integer_encoding.keys()):
            integer_encoding[j] = len(integer_encoding)
        subset_sentence_tokens_encoded[j] = integer_encoding[j]
        #subset_sentence_tokens_encoded.append(integer_encoding[i])
    return (subset_sentence_tokens_encoded)



for i in [10,20,30,40]:
    
    predicted_answers = []
    predicted_questions = []
    
    f1 = open('C:/Users/PRADEEP REDDY/Desktop/IIITH-Summer Internship/Open Domain Questoin Answering/Week-6/MLP1/Location/MLP_loc_'+str(i)+'_ans_pred.txt','rb')
    for line in f1:
        line = line.decode('utf-8').split('\n')[0]
        parts = line.split('@@@')
        ans = parts[1]
        q_p = parts[0].split(': ')
        q = q_p[1]
        
        predicted_questions.append(q)
        predicted_answers.append(ans)
    #print(predicted_questions,'\n\n')
    #print(len(predicted_questions))
    #print(predicted_answers,'\n\n\n')
    #print(len(predicted_answers))
    
    e_hits = 0.0
    p_hits = 0.0
    count = 0
    
    for p_i,p_q in enumerate(predicted_questions):
        n = 0
        for t_i,t_q in enumerate(actual_questions):
            if(p_q == t_q):
                n += 1
                pred_ans = [pred.replace("%", "") for pred in predicted_answers[p_i]]
                pred_ans = "".join(pred_ans)
                act_ans = [act.replace("%","") for act in actual_answers[t_i]]
                act_ans = "".join(act_ans)
                
                in1 = integer_encoding1(pred_ans)
                #print(in1)
                in2 = integer_encoding1(act_ans)
                #print(in2)
                
                
                
                import math
                def Cosine_Similarity(vec1, vec2):
                    common = set(vec1.keys()) & set(vec2.keys())
                    numerator = sum([vec1[x] * vec2[x] for x in common])
                    
                    sum1 = sum([vec1[x]**2 for x in vec1.keys()])
                    sum2 = sum([vec2[x]**2 for x in vec2.keys()])
                    denominator = (math.sqrt(sum1) * math.sqrt(sum2))
                    if not denominator:
                        return(0.0)
                    
                    else:
                        return(round(float(numerator) / denominator,1))
                
                cosine_similar = Cosine_Similarity(in1,in2)
                                
                match_ratio = ans_matching(pred_ans,act_ans)
                
                if(cosine_similar == 1):
                    e_hits += 1
                    p_hits += 1
                    break
                else:
                    if(match_ratio>=0.7):
                        p_hits += 1
                        break
                
                #if(match_ratio == 1.0):
                    #e_hits += 1
                    #p_hits += 1
                    #break
                #else:
                    #if(match_ratio >= 0.7):
                        #p_hits += 1
                        #break
                
                
        if(n == 0):
            count += 1
    
    print('K = ',i,'\n')
    print(len(predicted_questions)-count,'\n')
            
    print("\nLocation: \n")
    print("Percentage of\n"+"Exact_match: %.3f" %((e_hits/(len(predicted_questions)-count))*100)+"%")
    print("Percentage of\n"+"Partial_match: %.3f" %((p_hits/(len(predicted_questions)-count))*100)+'%')
print(len(predicted_questions))
# Out:
# K =  10
#
# 311
#
#
# Location:
#
# Percentage of
# Exact_match: 13.183%
# Percentage of
# Partial_match: 20.257%
# K =  20
#
# 321
#
#
# Location:
#
# Percentage of
# Exact_match: 14.330%
# Percentage of
# Partial_match: 21.184%
# K =  30
#
# 310
#
#
# Location:
#
# Percentage of
# Exact_match: 13.226%
# Percentage of
# Partial_match: 20.323%
# K =  40
#
# 310
#
#
# Location:
#
# Percentage of
# Exact_match: 14.194%
# Percentage of
# Partial_match: 21.613%
# 323
